# %%
import geopandas as gpd
import os
import os.path as path
import glob
import utils

# %%
uk_shapes = gpd.read_file(utils.uk_lau_dir)
uk_shapes = uk_shapes.to_crs(epsg=4326)

# %%
eu_shapes = gpd.read_file(utils.eu_lau_dir)
assert(eu_shapes.crs == uk_shapes.crs)

# %%
uk_shapes = uk_shapes.rename(columns={
    "LAD21CD": "LAU_ID",
    "LAD21NM": "LAU_NAME"
})
uk_shapes["CNTR_CODE"] = "UK"
uk_shapes["GISCO_ID"] = uk_shapes["LAU_ID"].apply(lambda x: "UK_" + x)

# %%
europe_shapes = gpd.pd.concat([eu_shapes, uk_shapes], ignore_index=True)

# %%
europe_shapes.columns
# Out:
# Index(['GISCO_ID', 'CNTR_CODE', 'LAU_ID', 'LAU_NAME', 'POP_2021', 'POP_DENS_2',
#        'AREA_KM2', 'YEAR', 'geometry', 'LAD21NMW', 'BNG_E', 'BNG_N', 'LONG',
#        'LAT', 'GlobalID'],
#       dtype='object')

# %%
europe_shapes = europe_shapes[['GISCO_ID', 'CNTR_CODE', 'LAU_ID', 'LAU_NAME', 'geometry']]

# %%
if not path.isdir(utils.lau_dir):
    os.mkdir(utils.lau_dir)
europe_shapes.to_file(path.join(utils.lau_dir, path.basename(utils.lau_dir)), driver="ESRI Shapefile")
