# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import os.path as path
import utils
import matplotlib.pyplot as plt

# %%
lau_df = gpd.read_file(path.join(utils.intermediate_data_dir, "drought_days_lau.geojson"))

# %%
max(lau_df["median_drought_days"].values)
# Out:
# np.float64(326.1)

# %%
plt.hist(lau_df["median_drought_days"].values, bins=365, range=(0, 365) )
plt.xlabel("median drought days per year")
plt.ylabel("Number of LAUs")
plt.show()

# %%
365/4
# Out:
# 91.25
